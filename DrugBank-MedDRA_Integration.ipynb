# %% [markdown]
# # Parse the DrugBank XML and extract TSVs

# %% [markdown]
# Run using Python 3 to avoid a non-ascii character error when writing to file with the csv module.

# %%
import os
import csv
import gzip
import collections
import re
import io
import json
import xml.etree.ElementTree as ET

import requests
import pandas
import numpy as np

# %%
import gseapy as gp
from gseapy.parser import Biomart

# %%
bm = Biomart(verbose=False, host="asia.ensembl.org")

# %%
xml_path = os.path.join('drugbank/', 'full database.xml')
with open(xml_path) as xml_file:
    tree = ET.parse(xml_file)
root = tree.getroot()

# %%
ns = '{http://www.drugbank.ca}'
inchikey_template = "{ns}calculated-properties/{ns}property[{ns}kind='InChIKey']/{ns}value"
inchi_template = "{ns}calculated-properties/{ns}property[{ns}kind='InChI']/{ns}value"

rows = list()
for i, drug in enumerate(root):
    row = collections.OrderedDict()
    assert drug.tag == ns + 'drug'
    row['type'] = drug.get('type')
    row['drugbank_id'] = drug.findtext(ns + "drugbank-id[@primary='true']")
    row['name'] = drug.findtext(ns + "name")
    row['description'] = drug.findtext(ns + "description")
    row['groups'] = [group.text for group in
        drug.findall("{ns}groups/{ns}group".format(ns = ns))]
    row['atc_codes'] = [code.get('code') for code in
        drug.findall("{ns}atc-codes/{ns}atc-code".format(ns = ns))]
    row['categories'] = [x.findtext(ns + 'category') for x in
        drug.findall("{ns}categories/{ns}category".format(ns = ns))]
    row['inchi'] = drug.findtext(inchi_template.format(ns = ns))
    row['inchikey'] = drug.findtext(inchikey_template.format(ns = ns))
    
    # Add drug aliases
    aliases = {
        elem.text for elem in 
        drug.findall("{ns}international-brands/{ns}international-brand".format(ns = ns)) +
        drug.findall("{ns}synonyms/{ns}synonym[@language='English']".format(ns = ns)) +
        drug.findall("{ns}international-brands/{ns}international-brand".format(ns = ns)) +
        drug.findall("{ns}products/{ns}product/{ns}name".format(ns = ns))

    }
    aliases.add(row['name'])
    row['aliases'] = sorted(aliases)

    rows.append(row)

# %%
alias_dict = {row['drugbank_id']: row['aliases'] for row in rows}
with open('./drugbank/data/aliases.json', 'w') as fp:
    json.dump(alias_dict, fp, indent=2, sort_keys=True)

# %%
def collapse_list_values(row):
    for key, value in row.items():
        if isinstance(value, list):
            row[key] = '|'.join(value)
    return row

rows = list(map(collapse_list_values, rows))

# %%
columns = ['drugbank_id', 'name', 'type', 'groups', 'atc_codes', 'categories', 'inchikey', 'inchi', 'description']
drugbank_df = pandas.DataFrame.from_dict(rows)[columns]
drugbank_df.head()
# Out:
#   drugbank_id                 name     type                    groups  \
# 0     DB00001            Lepirudin  biotech                  approved
# 1     DB00002            Cetuximab  biotech                  approved
# 2     DB00003         Dornase alfa  biotech                  approved
# 3     DB00004  Denileukin diftitox  biotech  approved|investigational
# 4     DB00005           Etanercept  biotech  approved|investigational
#
#   atc_codes                                         categories inchikey inchi  \
# 0   B01AE02  Amino Acids, Peptides, and Proteins|Anticoagul...     None  None
# 1   L01XC06  Amino Acids, Peptides, and Proteins|Antibodies...     None  None
# 2   R05CB13  Amino Acids, Peptides, and Proteins|Cough and ...     None  None
# 3   L01XX29  ADP Ribose Transferases|Amino Acids, Peptides,...     None  None
# 4   L04AB01  Agents reducing cytokine levels|Amino Acids, P...     None  None
#
#                                          description
# 0  Lepirudin is identical to natural hirudin exce...
# 1  Cetuximab is an epidermal growth factor recept...
# 2  Dornase alfa is a biosynthetic form of human d...
# 3  A recombinant DNA-derived cytotoxic protein co...
# 4  Dimeric fusion protein consisting of the extra...

# %%
drugbank_df.shape
# Out:
# (13563, 9)

# %%
drugbank_slim_df = drugbank_df[
    drugbank_df.groups.map(lambda x: 'approved' in x) &
    drugbank_df.inchi.map(lambda x: x is not None) &
    drugbank_df.type.map(lambda x: x == 'small molecule')
]
drugbank_slim_df.head()
# Out:
#    drugbank_id          name            type                    groups  \
# 5      DB00006   Bivalirudin  small molecule  approved|investigational
# 6      DB00007    Leuprolide  small molecule  approved|investigational
# 13     DB00014     Goserelin  small molecule                  approved
# 25     DB00027  Gramicidin D  small molecule                  approved
# 33     DB00035  Desmopressin  small molecule                  approved
#
#           atc_codes                                         categories  \
# 5           B01AE06  Amino Acids, Peptides, and Proteins|Anticoagul...
# 6   L02AE51|L02AE02  Adrenal Cortex Hormones|Agents Causing Muscle ...
# 13          L02AE03  Adrenal Cortex Hormones|Amino Acids, Peptides,...
# 25          R02AB30  Amino Acids, Peptides, and Proteins|Anti-Bacte...
# 33          H01BA02  Agents that produce hypertension|Amino Acids, ...
#
#                        inchikey  \
# 5   OIRCOABEOLEUMC-GEJPAHFPSA-N
# 6   GFIJNRVAKGFPGQ-LIJARHBVSA-N
# 13  BLCLNMBMMGCOAS-URPVMXJPSA-N
# 25  NDAYQJDHGXTBJL-MWWSRJDJSA-N
# 33  NFLWUMRGJYTJIN-PNIOQBSNSA-N
#
#                                                 inchi  \
# 5   InChI=1S/C98H138N24O33/c1-5-52(4)82(96(153)122...
# 6   InChI=1S/C59H84N16O12/c1-6-63-57(86)48-14-10-2...
# 13  InChI=1S/C59H84N18O14/c1-31(2)22-40(49(82)68-3...
# 25  InChI=1S/C96H135N19O16/c1-50(2)36-71(105-79(11...
# 33  InChI=1S/C46H64N14O12S2/c47-35(62)15-14-29-40(...
#
#                                           description
# 5   Bivalirudin is a synthetic 20 residue peptide ...
# 6   Leuprolide belongs to the general class of dru...
# 13  Goserelin is a synthetic hormone. In men, it s...
# 25  Gramcidin D is a heterogeneous mixture of thre...
# 33  Desmopressin (dDAVP), a synthetic analogue of ...

# %%
drugbank_slim_df.shape
# Out:
# (2618, 9)

# %%
# write drugbank tsv
path = os.path.join('drugbank/data', 'drugbank.tsv')
drugbank_df.to_csv(path, sep='\t', index=False)

# write slim drugbank tsv
path = os.path.join('drugbank/data', 'drugbank-slim.tsv')
drugbank_slim_df.to_csv(path, sep='\t', index=False)

# %% [markdown]
# ## Extract protein information

# %%
protein_rows = list()
for i, drug in enumerate(root):
    drugbank_id = drug.findtext(ns + "drugbank-id[@primary='true']")
    for category in ['target', 'enzyme', 'carrier', 'transporter']:
        proteins = drug.findall('{ns}{cat}s/{ns}{cat}'.format(ns=ns, cat=category))
        for protein in proteins:
            row = {'drugbank_id': drugbank_id, 'category': category}
            row['organism'] = protein.findtext('{}organism'.format(ns))
            row['known_action'] = protein.findtext('{}known-action'.format(ns))
            actions = protein.findall('{ns}actions/{ns}action'.format(ns=ns))
            row['actions'] = '|'.join(action.text for action in actions)
            uniprot_ids = [polypep.text for polypep in protein.findall(
                "{ns}polypeptide/{ns}external-identifiers/{ns}external-identifier[{ns}resource='UniProtKB']/{ns}identifier".format(ns=ns))]            
            if len(uniprot_ids) != 1:
                continue
            row['uniprot_id'] = uniprot_ids[0]
            ref_text = protein.findtext("{ns}references[@format='textile']".format(ns=ns))
            if str(type(ref_text)) != "<class 'NoneType'>" :
                pmids = re.findall(r'pubmed/([0-9]+)', ref_text)
                row['pubmed_ids'] = '|'.join(pmids)
            else:
                row['pubmed_ids'] = None
            protein_rows.append(row)

protein_df = pandas.DataFrame.from_dict(protein_rows)

# %%
# Read our uniprot to entrez_gene mapping
response = requests.get('http://git.dhimmel.com/uniprot/data/map/GeneID.tsv.gz', stream=True)
text = io.TextIOWrapper(gzip.GzipFile(fileobj=response.raw))
uniprot_df = pandas.read_table(text, engine='python')
uniprot_df.rename(columns={'uniprot': 'uniprot_id', 'GeneID': 'entrez_gene_id'}, inplace=True)

# merge uniprot mapping with protein_df
entrez_df = protein_df.merge(uniprot_df, how='inner')

# %%
columns = ['drugbank_id', 'category', 'uniprot_id', 'entrez_gene_id', 'organism',
           'known_action', 'actions', 'pubmed_ids']
entrez_df = entrez_df[columns]

# %%
path = os.path.join('drugbank/data', 'proteins.tsv')
entrez_df.to_csv(path, sep='\t', index=False)

# %%
entrez_df
# Out:
#       drugbank_id category uniprot_id  entrez_gene_id organism known_action  \
# 0         DB00001   target     P00734            2147   Humans          yes
# 1         DB00006   target     P00734            2147   Humans          yes
# 2         DB00025   enzyme     P00734            2147   Humans      unknown
# 3         DB00055   target     P00734            2147   Humans      unknown
# 4         DB00100   target     P00734            2147   Humans      unknown
# ...           ...      ...        ...             ...      ...          ...
# 27322     DB15493   target     Q8IXJ6           22933   Humans          yes
# 27323     DB15495   target     P35232            5245   Humans          yes
# 27324     DB15496   target     P35232            5245   Humans          yes
# 27325     DB15570   target     P51679            1233   Humans      unknown
# 27326     DB15593   target     P11532            1756   Humans          yes
#
#           actions pubmed_ids
# 0       inhibitor       None
# 1       inhibitor       None
# 2       activator       None
# 3                       None
# 4                       None
# ...           ...        ...
# 27322   inhibitor       None
# 27323   inhibitor       None
# 27324   inhibitor       None
# 27325  antagonist       None
# 27326     inducer       None
#
# [27327 rows x 8 columns]

# %%
entrez_df.actions.value_counts()
# Out:
#                                               11195
# inhibitor                                      5042
# substrate                                      4145
# antagonist                                     1564
# agonist                                        1101
#                                               ...
# binder|potentiator                                1
# intercalation                                     1
# desensitize the target                            1
# antagonist|inhibitory allosteric modulator        1
# inducer|acetylation                               1
# Name: actions, Length: 112, dtype: int64

# %%
# Number of unique genes with an interaction
len(set(entrez_df.entrez_gene_id))
# Out:
# 4628

# %%
# Number of unique drugs  with an interaction
len(set(entrez_df.drugbank_id))
# Out:
# 7057

# %%
drugbank_df.head()
# Out:
#   drugbank_id                 name     type                    groups  \
# 0     DB00001            Lepirudin  biotech                  approved
# 1     DB00002            Cetuximab  biotech                  approved
# 2     DB00003         Dornase alfa  biotech                  approved
# 3     DB00004  Denileukin diftitox  biotech  approved|investigational
# 4     DB00005           Etanercept  biotech  approved|investigational
#
#   atc_codes                                         categories inchikey inchi  \
# 0   B01AE02  Amino Acids, Peptides, and Proteins|Anticoagul...     None  None
# 1   L01XC06  Amino Acids, Peptides, and Proteins|Antibodies...     None  None
# 2   R05CB13  Amino Acids, Peptides, and Proteins|Cough and ...     None  None
# 3   L01XX29  ADP Ribose Transferases|Amino Acids, Peptides,...     None  None
# 4   L04AB01  Agents reducing cytokine levels|Amino Acids, P...     None  None
#
#                                          description
# 0  Lepirudin is identical to natural hirudin exce...
# 1  Cetuximab is an epidermal growth factor recept...
# 2  Dornase alfa is a biosynthetic form of human d...
# 3  A recombinant DNA-derived cytotoxic protein co...
# 4  Dimeric fusion protein consisting of the extra...

# %%
drugbank_df.columns
# Out:
# Index(['drugbank_id', 'name', 'type', 'groups', 'atc_codes', 'categories',
#        'inchikey', 'inchi', 'description'],
#       dtype='object')

# %%
# Maping multiple columns
drugbank_df.index = drugbank_df.drugbank_id
entrez_df.index = entrez_df.drugbank_id
for i in ['name', 'type', 'groups', 'atc_codes', 'categories', 'description']:
    entrez_df[i] = entrez_df.drugbank_id.map(drugbank_df[i])

# %%
entrez_df.head()
# Out:
#             drugbank_id category uniprot_id  entrez_gene_id organism  \
# drugbank_id
# DB00001         DB00001   target     P00734            2147   Humans
# DB00006         DB00006   target     P00734            2147   Humans
# DB00025         DB00025   enzyme     P00734            2147   Humans
# DB00055         DB00055   target     P00734            2147   Humans
# DB00100         DB00100   target     P00734            2147   Humans
#
#             known_action    actions pubmed_ids  \
# drugbank_id
# DB00001              yes  inhibitor       None
# DB00006              yes  inhibitor       None
# DB00025          unknown  activator       None
# DB00055          unknown                  None
# DB00100          unknown                  None
#
#                                                  name            type  \
# drugbank_id
# DB00001                                     Lepirudin         biotech
# DB00006                                   Bivalirudin  small molecule
# DB00025      Antihemophilic factor, human recombinant         biotech
# DB00055                              Drotrecogin alfa         biotech
# DB00100           Coagulation Factor IX (Recombinant)         biotech
#
#                                          groups atc_codes  \
# drugbank_id
# DB00001                                approved   B01AE02
# DB00006                approved|investigational   B01AE06
# DB00025                approved|investigational   B02BD02
# DB00055      approved|investigational|withdrawn   B01AD10
# DB00100                approved|investigational
#
#                                                     categories  \
# drugbank_id
# DB00001      Amino Acids, Peptides, and Proteins|Anticoagul...
# DB00006      Amino Acids, Peptides, and Proteins|Anticoagul...
# DB00025      Amino Acids, Peptides, and Proteins|Biological...
# DB00055      Amino Acids, Peptides, and Proteins|Anti-Infec...
# DB00100      Blood Coagulation Factors|Hemostatics|Increase...
#
#                                                    description
# drugbank_id
# DB00001      Lepirudin is identical to natural hirudin exce...
# DB00006      Bivalirudin is a synthetic 20 residue peptide ...
# DB00025      Human recombinant antihemophilic factor (AHF) ...
# DB00055      Drotrecogin alfa is activated human protein C ...
# DB00100      Recombinant Coagulation Factor IX is a purifie...

# %%
# Mapping Entrez to gene symbol
glist = np.unique(entrez_df.entrez_gene_id.values).tolist()
glist = [str(x) for x in glist if type(x) ==int]
results = bm.query(dataset='hsapiens_gene_ensembl', attributes=['entrezgene_id','hgnc_symbol'],#, 'go_id'],
                   filters={'entrezgene_id': glist})

# %%
entrez_df
# Out:
#             drugbank_id category uniprot_id  entrez_gene_id organism  \
# drugbank_id
# DB00001         DB00001   target     P00734            2147   Humans
# DB00006         DB00006   target     P00734            2147   Humans
# DB00025         DB00025   enzyme     P00734            2147   Humans
# DB00055         DB00055   target     P00734            2147   Humans
# DB00100         DB00100   target     P00734            2147   Humans
# ...                 ...      ...        ...             ...      ...
# DB15493         DB15493   target     Q8IXJ6           22933   Humans
# DB15495         DB15495   target     P35232            5245   Humans
# DB15496         DB15496   target     P35232            5245   Humans
# DB15570         DB15570   target     P51679            1233   Humans
# DB15593         DB15593   target     P11532            1756   Humans
#
#             known_action     actions pubmed_ids  \
# drugbank_id
# DB00001              yes   inhibitor       None
# DB00006              yes   inhibitor       None
# DB00025          unknown   activator       None
# DB00055          unknown                   None
# DB00100          unknown                   None
# ...                  ...         ...        ...
# DB15493              yes   inhibitor       None
# DB15495              yes   inhibitor       None
# DB15496              yes   inhibitor       None
# DB15570          unknown  antagonist       None
# DB15593              yes     inducer       None
#
#                                                  name            type  \
# drugbank_id
# DB00001                                     Lepirudin         biotech
# DB00006                                   Bivalirudin  small molecule
# DB00025      Antihemophilic factor, human recombinant         biotech
# DB00055                              Drotrecogin alfa         biotech
# DB00100           Coagulation Factor IX (Recombinant)         biotech
# ...                                               ...             ...
# DB15493                                      Cambinol  small molecule
# DB15495                                   Rocaglamide  small molecule
# DB15496                        Didesmethylrocaglamide  small molecule
# DB15570                                        FLX475  small molecule
# DB15593                                    Golodirsen         biotech
#
#                                          groups atc_codes  \
# drugbank_id
# DB00001                                approved   B01AE02
# DB00006                approved|investigational   B01AE06
# DB00025                approved|investigational   B02BD02
# DB00055      approved|investigational|withdrawn   B01AD10
# DB00100                approved|investigational
# ...                                         ...       ...
# DB15493                            experimental
# DB15495                            experimental
# DB15496                            experimental
# DB15570                         investigational
# DB15593                                approved
#
#                                                     categories  \
# drugbank_id
# DB00001      Amino Acids, Peptides, and Proteins|Anticoagul...
# DB00006      Amino Acids, Peptides, and Proteins|Anticoagul...
# DB00025      Amino Acids, Peptides, and Proteins|Biological...
# DB00055      Amino Acids, Peptides, and Proteins|Anti-Infec...
# DB00100      Blood Coagulation Factors|Hemostatics|Increase...
# ...                                                        ...
# DB15493                                            Pyrimidines
# DB15495                     Heterocyclic Compounds, Fused-Ring
# DB15496
# DB15570
# DB15593      Drugs that are Mainly Renally Excreted|Oligonu...
#
#                                                    description
# drugbank_id
# DB00001      Lepirudin is identical to natural hirudin exce...
# DB00006      Bivalirudin is a synthetic 20 residue peptide ...
# DB00025      Human recombinant antihemophilic factor (AHF) ...
# DB00055      Drotrecogin alfa is activated human protein C ...
# DB00100      Recombinant Coagulation Factor IX is a purifie...
# ...                                                        ...
# DB15493      Cambinol is a beta-naphtol derivative that inh...
# DB15495      Rocaglamide, also referred to as rocaglamide-A...
# DB15496      Didesmethylrocaglamide is a naturally-occurrin...
# DB15570      FLX475 is a small molecule CCR4 antagonist bei...
# DB15593      Golodirsen is a morpholino antisense oligomer ...
#
# [27327 rows x 14 columns]

# %%
entrez_df.index = np.arange(entrez_df.shape[0])
results =  results.dropna().drop_duplicates().reset_index(drop=True)
#entrez_df['hgnc_symbol'] = 0
entrez_df['hgnc_symbol'] = entrez_df.entrez_gene_id.map(results['hgnc_symbol'])
#for i in range(entrez_df.shape[0]):
#    entrez_df.iloc[i,-1] = results.loc[results.entrezgene_id==entrez_df.iloc[i,3],'hgnc_symbol'][0].values#entrez_df.entrez_gene_id.map(results['hgnc_symbol'])

# %%
results.shape
# Out:
# (3005, 2)

# %%
entrez_df.head()
# Out:
#   drugbank_id category uniprot_id  entrez_gene_id organism known_action  \
# 0     DB00001   target     P00734            2147   Humans          yes
# 1     DB00006   target     P00734            2147   Humans          yes
# 2     DB00025   enzyme     P00734            2147   Humans      unknown
# 3     DB00055   target     P00734            2147   Humans      unknown
# 4     DB00100   target     P00734            2147   Humans      unknown
#
#      actions pubmed_ids                                      name  \
# 0  inhibitor       None                                 Lepirudin
# 1  inhibitor       None                               Bivalirudin
# 2  activator       None  Antihemophilic factor, human recombinant
# 3                  None                          Drotrecogin alfa
# 4                  None       Coagulation Factor IX (Recombinant)
#
#              type                              groups atc_codes  \
# 0         biotech                            approved   B01AE02
# 1  small molecule            approved|investigational   B01AE06
# 2         biotech            approved|investigational   B02BD02
# 3         biotech  approved|investigational|withdrawn   B01AD10
# 4         biotech            approved|investigational
#
#                                           categories  \
# 0  Amino Acids, Peptides, and Proteins|Anticoagul...
# 1  Amino Acids, Peptides, and Proteins|Anticoagul...
# 2  Amino Acids, Peptides, and Proteins|Biological...
# 3  Amino Acids, Peptides, and Proteins|Anti-Infec...
# 4  Blood Coagulation Factors|Hemostatics|Increase...
#
#                                          description hgnc_symbol
# 0  Lepirudin is identical to natural hirudin exce...         RET
# 1  Bivalirudin is a synthetic 20 residue peptide ...         RET
# 2  Human recombinant antihemophilic factor (AHF) ...         RET
# 3  Drotrecogin alfa is activated human protein C ...         RET
# 4  Recombinant Coagulation Factor IX is a purifie...         RET

# %%
entrez_df.to_csv('DrugBank_Drug_Target.csv')

# %% [markdown]
# ### Integrate MedDRA side effect database

# %%
se_df = pandas.read_csv('MedDRA/side-effects.tsv',sep='\t') #pandas.read_csv('MedDRA/meddra_freq_with_cols.tsv',index_col=0)

# %%
se_df.head(5)
# Out:
#   drugbank_id                                      drugbank_name  \
# 0     DB07768  (10ALPHA,13ALPHA,14BETA,17ALPHA)-17-HYDROXYAND...
# 1     DB07768  (10ALPHA,13ALPHA,14BETA,17ALPHA)-17-HYDROXYAND...
# 2     DB07768  (10ALPHA,13ALPHA,14BETA,17ALPHA)-17-HYDROXYAND...
# 3     DB07768  (10ALPHA,13ALPHA,14BETA,17ALPHA)-17-HYDROXYAND...
# 4     DB07768  (10ALPHA,13ALPHA,14BETA,17ALPHA)-17-HYDROXYAND...
#
#   umls_cui_from_meddra          side_effect_name
# 0             C0000729          Abdominal cramps
# 1             C0000737            Abdominal pain
# 2             C0232492      Abdominal pain upper
# 3             C0740651         Abdominal symptom
# 4             C0877331  Abnormal clotting factor

# %%
se_df_unique = se_df.groupby('drugbank_id').agg({'umls_cui_from_meddra': lambda x: list(x),'umls_cui_from_meddra': lambda x: list(x),
                                      'side_effect_name': lambda x: list(x),'side_effect_name': lambda x: list(x),
                                     })
se_df_unique.head(2)
# Out:
#                                           umls_cui_from_meddra  \
# drugbank_id
# DB00014      [C0000737, C0702166, C0948089, C0559546, C0233...
# DB00035      [C1291077, C0000729, C0000731, C0000737, C0233...
#
#                                               side_effect_name
# drugbank_id
# DB00014      [Abdominal pain, Acne, Acute coronary syndrome...
# DB00035      [Abdominal bloating, Abdominal cramps, Abdomin...

# %%
# Maping side effect to drug bank using drukbank_id columns
#se_df_unique.index = se_df_unique.drugbank_id
#entrez_df.index = entrez_df.drugbank_id
for i in ['umls_cui_from_meddra', 'side_effect_name']:
    entrez_df[i] = entrez_df.drugbank_id.map(se_df_unique[i])

# %% [markdown]
# ### Integrate MedDRA indication database

# %%
ind_df = pandas.read_csv('MedDRA/indications.tsv',sep='\t')
ind_df.head()
# Out:
#   drugbank_id drugbank_name  pubchem_id stitch_id_flat umls_cui_from_label  \
# 0     DB00014     Goserelin       47725   CID100047725            C0002871
# 1     DB00014     Goserelin       47725   CID100047725            C0006142
# 2     DB00014     Goserelin       47725   CID100047725            C0006826
# 3     DB00014     Goserelin       47725   CID100047725            C0014175
# 4     DB00014     Goserelin       47725   CID100047725            C0025323
#
#              method                  concept_name meddra_type  \
# 0      text_mention                        Anemia          PT
# 1    NLP_indication  Malignant neoplasm of breast          PT
# 2  NLP_precondition           Malignant Neoplasms          PT
# 3    NLP_indication                 Endometriosis          PT
# 4      text_mention                   Menorrhagia          PT
#
#   umls_cui_from_meddra         meddra_name
# 0             C0002871             Anaemia
# 1             C0006142       Breast cancer
# 2             C0006826  Neoplasm malignant
# 3             C0014175       Endometriosis
# 4             C0025323         Menorrhagia

# %%
ind_df.method.unique()
# Out:
# array(['text_mention', 'NLP_indication', 'NLP_precondition'], dtype=object)

# %%
ind_df_unique = ind_df.groupby('drugbank_id').agg({'umls_cui_from_meddra': lambda x: list(x),'umls_cui_from_meddra': lambda x: list(x),
                                                   'meddra_name': lambda x: list(x),'meddra_name': lambda x: np.unique(list(x)).tolist(),
                                                   })
ind_df_unique.columns = ['umls_cui_from_meddra','Meddra_Indication']
ind_df_unique.head(2)
# Out:
#                                           umls_cui_from_meddra  \
# drugbank_id
# DB00014      [C0002871, C0006142, C0006826, C0014175, C0025...
# DB00035      [C0008533, C0011848, C0032617, C0014394, C0018...
#
#                                              Meddra_Indication
# drugbank_id
# DB00014      [Anaemia, Bone cancer metastatic, Breast cance...
# DB00035      [Blood osmolarity decreased, Diabetes insipidu...

# %%
# Maping indication to drug bank using drukbank_id columns
#se_df_unique.index = se_df_unique.drugbank_id
#entrez_df.index = entrez_df.drugbank_id
for i in [ 'Meddra_Indication']:
    entrez_df[i] = entrez_df.drugbank_id.map(ind_df_unique[i])

# %%
entrez_df.to_csv('DrugBank_Drug_Target_SideEffect_Indication.csv')

# %%
idx = se_df.side_effect_name.str.lower().str.contains('titis')
se_df_ = se_df.loc[idx,:]
se_df_
# Out:
#        drugbank_id                                      drugbank_name  \
# 15         DB07768  (10ALPHA,13ALPHA,14BETA,17ALPHA)-17-HYDROXYAND...
# 109        DB07768  (10ALPHA,13ALPHA,14BETA,17ALPHA)-17-HYDROXYAND...
# 110        DB07768  (10ALPHA,13ALPHA,14BETA,17ALPHA)-17-HYDROXYAND...
# 111        DB07768  (10ALPHA,13ALPHA,14BETA,17ALPHA)-17-HYDROXYAND...
# 112        DB07768  (10ALPHA,13ALPHA,14BETA,17ALPHA)-17-HYDROXYAND...
# ...            ...                                                ...
# 153522     DB08439                                          parecoxib
# 153549     DB08439                                          parecoxib
# 153576     DB05383                                     pimagedine HCl
# 153605     DB07424  tripotassium (1R)-4-biphenyl-4-yl-1-phosphonat...
# 153645     DB05738                         vapitadine dihydrochloride
#
#        umls_cui_from_meddra             side_effect_name
# 15                 C0162820  Allergic contact dermatitis
# 109                C0011603                   Dermatitis
# 110                C0234894         Dermatitis acneiform
# 111                C0011615            Dermatitis atopic
# 112                C0085932           Dermatitis bullous
# ...                     ...                          ...
# 153522             C0019158                    Hepatitis
# 153549             C0030305                 Pancreatitis
# 153576             C0011603                   Dermatitis
# 153605             C0011603                   Dermatitis
# 153645             C0011603                   Dermatitis
#
# [4053 rows x 4 columns]

# %%
#entrez_df = entrez_df.drop(columns=['meddra_name'])

# %%
idx = np.logical_or(se_df.side_effect_name.str.lower().str.contains('toxic') , se_df.side_effect_name.str.contains('poisining'))
se_df_ = se_df.loc[idx,:]
se_df_.shape
# Out:
# (819, 4)

# %%
se_df_
# Out:
#        drugbank_id                                      drugbank_name  \
# 1214       DB08567  (1S,4S)-4-(3,4-dichlorophenyl)-N-methyl-1,2,3,...
# 1329       DB07129         (2R)-1-(2,6-dimethylphenoxy)propan-2-amine
# 1678       DB08298    (2S)-2-(6-methoxynaphthalen-2-yl)propanoic acid
# 1803       DB02932  (2r)-N-[4-Cyano-3-(Trifluoromethyl)Phenyl]-3-[...
# 2084       DB08472  (3R)-N-methyl-3-phenyl-3-[4-(trifluoromethyl)p...
# ...            ...                                                ...
# 153072     DB05291                                    lidocaine patch
# 153142     DB05291                                    lidocaine patch
# 153330     DB05302                                   naltrexone depot
# 153565     DB08439                                          parecoxib
# 153625     DB07424  tripotassium (1R)-4-biphenyl-4-yl-1-phosphonat...
#
#        umls_cui_from_meddra            side_effect_name
# 1214               C0014518  Toxic epidermal necrolysis
# 1329               C0919924          Pulmonary toxicity
# 1678               C0014518  Toxic epidermal necrolysis
# 1803               C0235378              Hepatotoxicity
# 2084               C0876994              Cardiotoxicity
# ...                     ...                         ...
# 153072             C3160947                CNS toxicity
# 153142             C0235032               Neurotoxicity
# 153330             C0235378              Hepatotoxicity
# 153565             C0014518  Toxic epidermal necrolysis
# 153625             C0728899                Intoxication
#
# [819 rows x 4 columns]

# %%
# Selecting side effects with Toxicity only
se_df_ = se_df.loc[idx,:]
se_df_unique_ = se_df_.groupby('drugbank_id').agg({'umls_cui_from_meddra': lambda x: list(x),'umls_cui_from_meddra': lambda x: list(x),
                                                 'side_effect_name': lambda x: list(x),'side_effect_name': lambda x: list(x),
                                                 })
for i in ['umls_cui_from_meddra', 'side_effect_name']:
    entrez_df[i] = entrez_df.drugbank_id.map(se_df_unique_[i])
entrez_df.to_csv('DrugBank_Drug_Target_Toxicity_Only_Indication.csv')

# %%
entrez_df.head()
# Out:
#   drugbank_id category uniprot_id  entrez_gene_id organism known_action  \
# 0     DB00001   target     P00734            2147   Humans          yes
# 1     DB00006   target     P00734            2147   Humans          yes
# 2     DB00025   enzyme     P00734            2147   Humans      unknown
# 3     DB00055   target     P00734            2147   Humans      unknown
# 4     DB00100   target     P00734            2147   Humans      unknown
#
#      actions pubmed_ids                                      name  \
# 0  inhibitor       None                                 Lepirudin
# 1  inhibitor       None                               Bivalirudin
# 2  activator       None  Antihemophilic factor, human recombinant
# 3                  None                          Drotrecogin alfa
# 4                  None       Coagulation Factor IX (Recombinant)
#
#              type                              groups atc_codes  \
# 0         biotech                            approved   B01AE02
# 1  small molecule            approved|investigational   B01AE06
# 2         biotech            approved|investigational   B02BD02
# 3         biotech  approved|investigational|withdrawn   B01AD10
# 4         biotech            approved|investigational
#
#                                           categories  \
# 0  Amino Acids, Peptides, and Proteins|Anticoagul...
# 1  Amino Acids, Peptides, and Proteins|Anticoagul...
# 2  Amino Acids, Peptides, and Proteins|Biological...
# 3  Amino Acids, Peptides, and Proteins|Anti-Infec...
# 4  Blood Coagulation Factors|Hemostatics|Increase...
#
#                                          description hgnc_symbol  \
# 0  Lepirudin is identical to natural hirudin exce...         RET
# 1  Bivalirudin is a synthetic 20 residue peptide ...         RET
# 2  Human recombinant antihemophilic factor (AHF) ...         RET
# 3  Drotrecogin alfa is activated human protein C ...         RET
# 4  Recombinant Coagulation Factor IX is a purifie...         RET
#
#   umls_cui_from_meddra side_effect_name Meddra_Indication
# 0                  NaN              NaN               NaN
# 1                  NaN              NaN               NaN
# 2                  NaN              NaN               NaN
# 3                  NaN              NaN               NaN
# 4                  NaN              NaN               NaN

# %%
# Drugbank entries with SE only
entrez_df_with_se = entrez_df.loc[~entrez_df.side_effect_name.isna(),:]

# %%
entrez_df_with_se.head()
# Out:
#     drugbank_id category uniprot_id  entrez_gene_id organism known_action  \
# 121     DB00281   target     P00533            1956   Humans      unknown
# 122     DB00317   target     P00533            1956   Humans          yes
# 123     DB00530   target     P00533            1956   Humans          yes
# 124     DB01259   target     P00533            1956   Humans          yes
# 137     DB08916   target     P00533            1956   Humans          yes
#
#         actions pubmed_ids       name            type  \
# 121  antagonist       None  Lidocaine  small molecule
# 122  antagonist       None  Gefitinib  small molecule
# 123  antagonist       None  Erlotinib  small molecule
# 124  antagonist       None  Lapatinib  small molecule
# 137   inhibitor       None   Afatinib  small molecule
#
#                        groups  \
# 121     approved|vet_approved
# 122  approved|investigational
# 123  approved|investigational
# 124  approved|investigational
# 137                  approved
#
#                                              atc_codes  \
# 121  S01HA07|D04AB01|R02AD02|C01BB01|S02DA01|N01BB5...
# 122                                            L01XE02
# 123                                            L01XE03
# 124                                            L01XE07
# 137                                            L01XE13
#
#                                             categories  \
# 121  Agents for Treatment of Hemorrhoids and Anal F...
# 122  Antineoplastic Agents|Antineoplastic and Immun...
# 123  Antineoplastic Agents|Antineoplastic and Immun...
# 124  Antineoplastic Agents|Antineoplastic and Immun...
# 137  Amides|Antineoplastic Agents|Antineoplastic an...
#
#                                            description hgnc_symbol  \
# 121  Ever since its discovery and availability for ...      ACOT13
# 122  Gefitinib (originally coded ZD1839) is a drug ...      ACOT13
# 123  Erlotinib is an inhibitor of the epidermal gro...      ACOT13
# 124  Lapatinib is an anti-cancer drug developed by ...      ACOT13
# 137  Afatinib is a 4-anilinoquinazoline tyrosine ki...      ACOT13
#
#      umls_cui_from_meddra                      side_effect_name  \
# 121  [C3160947, C0235032]         [CNS toxicity, Neurotoxicity]
# 122            [C0919924]                  [Pulmonary toxicity]
# 123  [C0235378, C0919924]  [Hepatotoxicity, Pulmonary toxicity]
# 124  [C0876994, C0235378]      [Cardiotoxicity, Hepatotoxicity]
# 137            [C0919924]                  [Pulmonary toxicity]
#
#                                      Meddra_Indication
# 121  [Acute coronary syndrome, Acute myocardial inf...
# 122  [Haemoglobin, Haemorrhage, Idiopathic pulmonar...
# 123  [Metastases to pancreas, Neoplasm, Neoplasm ma...
# 124  [Breast cancer, Breast cancer stage IV, Diseas...
# 137  [Neoplasm, Non-small cell lung cancer, Small c...
